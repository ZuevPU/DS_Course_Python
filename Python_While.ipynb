# %% [markdown]
# # Допустим заранее количество повторений цикла неизвестно, тогда применяется конструкция, которая называется циклом while:

# %% [markdown]
# <img src='https://enot-doma.ru/wp-content/uploads/2017/04/04.04.2017_01-1.jpg'>

# %% [markdown]
# ### Пример 1. Еноты или "Что не так с программой?"

# %%
raccoon = 6
while raccoon > 0:
print(raccoon)
raccoon = raccoon - 1
# Out:
#   File "<ipython-input-17-e495f811cfa2>", line 3
#     print(raccoon)
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# <img src="https://cf.ppt-online.org/files/slide/r/rG9WUCfeoFZh1s76Q0PMqbijTRwX35zJucOYnx/slide-6.jpg">

# %% [markdown]
# ### Правильный вариант программы

# %%
raccoon = 6
while raccoon > 0:
    print(raccoon)
    raccoon = raccoon - 1
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# В примере цикл while выполняется до тех пор, ПОКА число енотов в условии положительное. На каждом шаге цикла мы переменную raccoon уменьшаем на 1, чтобы не уйти в бесконечный цикл, когда условие всегда будет являться истинным.
#
# Рассмотрим подробнее ход выполнения программы.
# В начале работы программы переменная raccoon равна 6, затем попадаем в цикл while, т.к. условие raccoon > 0 будет являться истинным (вернет значение True). В теле цикла вызывается функция print(), которая отобразит на экране текущее значение переменной raccoon. Далее переменная уменьшится на 1 и снова произойдет проверка условия while, т.е. 2 > 0 (вернет True). Попадаем в цикл и действия повторяются до тех пор, пока не дойдем до условия 0 > 0. В этом случае вернется логическое значение False и цикл while не сработает

# %% [markdown]
# ### Пример 2. Start artificial intelligence

# %%
while True:
    text = input("Введите число или енот или стоп для выхода: ")
    if text == "стоп":
        print("Выход из программы! До встречи!")
        break # инструкция выхода из цикла
    elif text == '1':
        print("Число 1")
    elif text == 'енот':
        print("Это енот")
    else:
        print("Что это?!")
# Out:
# Введите число или енот или стоп для выхода: 2
# Что это?!
# Введите число или енот или стоп для выхода: 4
# Что это?!
# Введите число или енот или стоп для выхода: 1
# Число 1
# Введите число или енот или стоп для выхода: енот
# Это Енот
# Введите число или енот или стоп для выхода: стоп
# Выход из программы! До встречи!

# %% [markdown]
# Программа выполняется в бесконечном цикле, т.к. True всегда является истиной. Внутри цикла происходит ввод значения с клавиатуры и проверка введенного значения. Инструкция break осуществляет выход из цикла. В подобных программах необходимо внимательно следить за преобразованием типов данных.

# %% [markdown]
# ## Задачи для решения

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Дано число 923 451. Получить на экране:
# >```
# 92345
# 9234
# 923
# 92
# 9
# 0
# ```

# %% [markdown]
# #### вариант решения №1

# %%
n = 923451
print(n//10)
print(n//100)
print(n//1000)
print(n//10000)
print(n//100000)
print(n//1000000)
# Out:
# 92345
# 9234
# 923
# 92
# 9
# 0

# %% [markdown]
# #### вариант решения №2

# %%
n = 923451
n = n//10
print(n)
n = n//10
print(n)
n = n//10
print(n)
n = n//10
print(n)
n = n//10
print(n)
n = n//10
print(n)
# Out:
# 92345
# 9234
# 923
# 92
# 9
# 0

# %% [markdown]
# #### вариант решения №3

# %%
n = 923451
while n != 0:
    n = n//10
    print(n)

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Дано число 923 451. Получить на экране:
# >```
# 1
# 15
# 154
# 1543
# 15432
# 154329
# ```

# %%
n = 923451
a = 0
while n != 0:
    a = a * 10 + n % 10
    print(a)
    n = n//10
# Out:
# 1
# 15
# 154
# 1543
# 15432
# 154329

# %% [markdown]
# ### Задача 3.

# %% [markdown]
# Напишите программу, которая получает с клавиатуры количество повторений и выводит столько же раз какое-нибудь сообщение.
# Пример:
# >```
# Сколько раз повторить? 3
# Привет!
# Привет!
# Привет!```

# %%
i=0
number = int(input('Сколько раз повторить? '))
while i<number:
    print('Привет!')
    i+=1
# Out:
# Сколько раз повторить? 5
# Привет!
# Привет!
# Привет!
# Привет!
# Привет!

# %% [markdown]
# ### Задача 4.

# %% [markdown]
# Дано натуральное (целое положительное) число n. Определить сумму цифр в нем.

# %%
number = int(input("Введите целое положительное число: "))
s = 0
while number > 0:
    s = s + number % 10
    number = number // 10
print("Сумма цифр в числе =",s)
# Out:
# Введите целое положительное число: 1234
# Сумма цифр в числе = 10

# %% [markdown]
# ### Задача 5.

# %% [markdown]
# Дано натуральное (целое положительное) число n. Определить количество цифр в нем.

# %%
number = int(input("Введите целое положительное число: "))
n = 0
while number > 0:
    n = n + 1
    number = number // 10
print("Кол-во цифр в числе =",n)
# Out:
# Введите целое положительное число: 1234
# Кол-во цифр в числе = 4

# %% [markdown]
# ### Задача 6.

# %% [markdown]
# Напишите программу, которая получает с клавиатуры натуральное число и определяет, сколько раз в его десятичной записи встречается цифра 1.
# Пример:
# > ```
# Введите число? 311
# Единиц: 2 ```

# %%
a = int(input('Введите число: '))
count = 0
while a != 0:
    if (a % 10) == 1:
        count += 1
    a = a // 10
print(count)
# Out:
# Введите число: 1234
# 1

# %% [markdown]
# ### Задача 7.

# %% [markdown]
# Напишите программу, которая получает с клавиатуры натуральное число и находит наибольшую цифру в его десятичной записи.
# Пример:
# >```
# Введите число? 311
# Наибольшая цифра: 3```

# %%
a = int(input('Введите число: '))
maximum = 0
while a != 0:
    if (a % 10) > maximum:
        maximum = a % 10
    a = a // 10
print(maximum)
# Out:
# Введите число: 123
# 3

# %% [markdown]
# ### Задача 8.

# %% [markdown]
# Напишите программу, которая получает с клавиатуры натуральное число и определяет, есть ли в его десятичной записи одинаковые цифры, стоящие рядом.

# %%
a = int(input('Введите число: '))
count = 0
while a != 0:
    if (a % 10) == ((a // 10)% 10):
        count += 1
    a = a // 10
if count > 0:
    print('Да')
else:
    print('Нет')
# Out:
# Введите число: 23411
# Да

# %% [markdown]
# ### Задача 9.

# %% [markdown]
# Определение m-й справа цифры числа.

# %% [markdown]
# ### Задача 10.

# %% [markdown]
# Определение m-й слева цифры числа.

# %% [markdown]
# ### Задача 11.

# %% [markdown]
#   Определение номера максимальной цифры числа при счете справа налево.

# %% [markdown]
# ### Задача 12.

# %% [markdown]
# Определение номера минимальной цифры числа при счете справа налево.

# %% [markdown]
# ## И еще немного теории

# %% [markdown]
# Цикл while (“пока”) позволяет выполнять одну и ту же последовательность действий, пока проверяемое условие истинно.
#
# Условие записывается до тела цикла и проверяется до выполнения тела цикла. Как правило, цикл while используется, когда невозможно заранее определить точно количество шагов.
#
# Синтаксис цикла while в простейшем случае выглядит так:
#
# while условие:
#     блок инструкций
#
# При выполнении цикла while сначала проверяется условие. Если оно ложно, то выполнение цикла прекращается и управление передается на следующую инструкцию после тела цикла while. Если условие истинно, то выполняется инструкция, после чего условие проверяется снова и снова выполняется инструкция. Так продолжается до тех пор, пока условие будет истинно. Как только условие станет ложно, работа цикла завершится и управление передастся следующей инструкции после цикла.
#
# Например, следующий фрагмент программы напечатает на экран квадраты всех целых чисел от 1 до 10:
#
# i = 1
# while i <= 10:
#     print(i) i += 1
#
#  В этом примере переменная i внутри цикла изменяется от 1 до 10. Такая переменная, значение которой меняется с каждым новым проходом цикла, называется счетчиком. Заметим, что после выполнения этого фрагмента значение переменной i будет равно 11, поскольку именно при i==11 условие i<=10 впервые перестанет выполняться.
#
# Вот еще один пример использования цикла while для определения количества цифр натурального числа n:
#
# n = int(input())
# length = 0
#
# while n > 0:
#     n //= 10
#     length += 1
#
#  В этом цикле мы отбрасываем по одной цифре числа, начиная с конца, что эквивалентно целочисленному делению на 10 (n //= 10), при этом считаем в переменной length, сколько раз это было сделано.
#
# Впрочем, в языке Питон есть и другой способ решения этой задачи: length = len(str(i))
#
# Еще раз подчеркнем отличие цикла while от цикла for: while используется тогда, когда мы заранее не знаем, сколько раз должны повторять некоторое действие.
#
# Цикл while в Python
#
# Цикл while (“пока”) позволяет выполнять одну и ту же последовательность действий, пока проверяемое условие истинно.
#
# Условие записывается до тела цикла и проверяется до выполнения тела цикла. Как правило, цикл while используется, когда невозможно заранее определить точно количество шагов.
#
# Синтаксис цикла while в простейшем случае выглядит так:
#
# while условие:
#     блок инструкций
#
# При выполнении цикла while сначала проверяется условие. Если оно ложно, то выполнение цикла прекращается и управление передается на следующую инструкцию после тела цикла while. Если условие истинно, то выполняется инструкция, после чего условие проверяется снова и снова выполняется инструкция. Так продолжается до тех пор, пока условие будет истинно. Как только условие станет ложно, работа цикла завершится и управление передастся следующей инструкции после цикла.
#
# Например, следующий фрагмент программы напечатает на экран квадраты всех целых чисел от 1 до 10:
#
# i = 1
# while i <= 10:
#     print(i) i += 1
#
#  В этом примере переменная i внутри цикла изменяется от 1 до 10. Такая переменная, значение которой меняется с каждым новым проходом цикла, называется счетчиком. Заметим, что после выполнения этого фрагмента значение переменной i будет равно 11, поскольку именно при i==11 условие i<=10 впервые перестанет выполняться.
#
# Вот еще один пример использования цикла while для определения количества цифр натурального числа n:
#
# n = int(input())
# length = 0
#
# while n > 0:
#     n //= 10
#     length += 1
#
#  В этом цикле мы отбрасываем по одной цифре числа, начиная с конца, что эквивалентно целочисленному делению на 10 (n //= 10), при этом считаем в переменной length, сколько раз это было сделано.
